# %%
import pandas as pd
import numpy as np
import re
import random

# %%
df_upper1 = pd.read_excel(r'Sources_coding_complete_20-21.xlsx')
df_upper1 = df_upper1.iloc[2:]
df_upper1["intro/upper"] = "upper"
df_upper2 = pd.read_excel(r'Sources_coding_upper_21-22.xlsx')
df_upper2 = df_upper2.iloc[2:]
df_upper2["intro/upper"] = "upper"
df_intro = pd.read_excel(r'Sources_coding_intro_21-22.xlsx')
df_intro = df_intro.iloc[2:]
df_intro["intro/upper"] = "intro"

# %%
df = pd.concat([df_upper1,df_upper2])

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()
df10 = pd.DataFrame()
df1[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q107_1_3","PM1_PLO","PM1_SE","PM1_PsMs","PM1_CSV","Q78.1"]]
df2[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q107_2_3","PM2_PLO","PM2_SE","PM2_PsMs","PM2_CSV","Q78.1"]]
df3[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q107_3_3","PM3_PLO","PM3_SE","PM3_PsMs","PM3_CSV","Q78.1"]]
df4[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q107_4_3","PM4_PLO","PM4_SE","PM4_PsMs","PM4_CSV","Q78.1"]]
df5[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q107_5_3","PM5_PLO","PM5_SE","PM5_PsMs","PM5_CSV","Q78.1"]]
df6[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q107_6_3","PM6_PLO","PM6_SE","PM6_PsMs","PM6_CSV","Q78.1"]]
df7[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q107_7_3","PM7_PLO","PM7_SE","PM7_PsMs","PM7_CSV","Q78.1"]]
df8[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q107_8_3","PM8_PLO","PM8_SE","PM8_PsMs","PM8_CSV","Q78.1"]]
df9[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q107_9_3","PM9_PLO","PM9_SE","PM9_PsMs","PM9_CSV","Q78.1"]]
df10[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q107_10_3","PM10_PLO","PM10_SE","PM10_PsMs","PM10_CSV","Q78.1"]]

df1i = pd.DataFrame()
df2i = pd.DataFrame()
df3i = pd.DataFrame()
df4i = pd.DataFrame()
df5i = pd.DataFrame()
df6i = pd.DataFrame()
df7i = pd.DataFrame()
df8i = pd.DataFrame()
df9i = pd.DataFrame()
df10i = pd.DataFrame()
df1i[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df_intro[["ResponseId","intro/upper","Q17_1_3","PM1_PLO","PM1_SE","PM1_PsMs","PM1_CSV","Q78"]]
df2i[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df_intro[["ResponseId","intro/upper","Q17_2_3","PM2_PLO","PM2_SE","PM2_PsMs","PM2_CSV","Q78"]]
df3i[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df_intro[["ResponseId","intro/upper","Q17_3_3","PM3_PLO","PM3_SE","PM3_PsMs","PM3_CSV","Q78"]]
df4i[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df_intro[["ResponseId","intro/upper","Q17_4_3","PM4_PLO","PM4_SE","PM4_PsMs","PM4_CSV","Q78"]]
df5i[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df_intro[["ResponseId","intro/upper","Q17_5_3","PM5_PLO","PM5_SE","PM5_PsMs","PM5_CSV","Q78"]]
df6i[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df_intro[["ResponseId","intro/upper","Q17_6_3","PM6_PLO","PM6_SE","PM6_PsMs","PM6_CSV","Q78"]]
df7i[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df_intro[["ResponseId","intro/upper","Q17_7_3","PM7_PLO","PM7_SE","PM7_PsMs","PM7_CSV","Q78"]]
df8i[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df_intro[["ResponseId","intro/upper","Q17_8_3","PM8_PLO","PM8_SE","PM8_PsMs","PM8_CSV","Q78"]]
df9i[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df_intro[["ResponseId","intro/upper","Q17_9_3","PM9_PLO","PM9_SE","PM9_PsMs","PM9_CSV","Q78"]]
df10i[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df_intro[["ResponseId","intro/upper","Q17_10_3","PM10_PLO","PM10_SE","PM10_PsMs","PM10_CSV","Q78"]]

pdList = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df1i,df2i,df3i,df4i,df5i,df6i,df7i,df8i,df9i,df10i]
PM = pd.concat(pdList)

PM["Exp"] = "PM"
PM = PM[PM["Q"].notnull()]

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()
df10 = pd.DataFrame()
#df1[["ResponseId","Q43","BM_PLO","BM_SE","BM_PsMs","BM_CSV"]] = df[["ResponseId","Q43_1_3","BM1_PLO","BM1_SE","BM1_PsMs","BM1_CSV"]]
#df2[["ResponseId","Q43","BM_PLO","BM_SE","BM_PsMs","BM_CSV"]] = df[["ResponseId","Q43_2_3","BM2_PLO","BM2_SE","BM2_PsMs","BM2_CSV"]]
#df3[["ResponseId","Q43","BM_PLO","BM_SE","BM_PsMs","BM_CSV"]] = df[["ResponseId","Q43_3_3","BM3_PLO","BM3_SE","BM3_PsMs","BM3_CSV"]]
#df4[["ResponseId","Q43","BM_PLO","BM_SE","BM_PsMs","BM_CSV"]] = df[["ResponseId","Q43_4_3","BM4_PLO","BM4_SE","BM4_PsMs","BM4_CSV"]]
#df5[["ResponseId","Q43","BM_PLO","BM_SE","BM_PsMs","BM_CSV"]] = df[["ResponseId","Q43_5_3","BM5_PLO","BM5_SE","BM5_PsMs","BM5_CSV"]]
#df6[["ResponseId","Q43","BM_PLO","BM_SE","BM_PsMs","BM_CSV"]] = df[["ResponseId","Q43_6_3","BM6_PLO","BM6_SE","BM6_PsMs","BM6_CSV"]]
#df7[["ResponseId","Q43","BM_PLO","BM_SE","BM_PsMs","BM_CSV"]] = df[["ResponseId","Q43_7_3","BM7_PLO","BM7_SE","BM7_PsMs","BM7_CSV"]]
#df8[["ResponseId","Q43","BM_PLO","BM_SE","BM_PsMs","BM_CSV"]] = df[["ResponseId","Q43_8_3","BM8_PLO","BM8_SE","BM8_PsMs","BM8_CSV"]]
#df9[["ResponseId","Q43","BM_PLO","BM_SE","BM_PsMs","BM_CSV"]] = df[["ResponseId","Q43_9_3","BM9_PLO","BM9_SE","BM9_PsMs","BM9_CSV"]]
#df10[["ResponseId","Q43","BM_PLO","BM_SE","BM_PsMs","BM_CSV"]] = df[["ResponseId","Q43_10_3","BM10_PLO","BM10_SE","BM10_PsMs","BM10_CSV"]]
df1[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q43_1_3","BM1_PLO","BM1_SE","BM1_PsMs","BM1_CSV","Q78.1"]]
df2[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q43_2_3","BM2_PLO","BM2_SE","BM2_PsMs","BM2_CSV","Q78.1"]]
df3[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q43_3_3","BM3_PLO","BM3_SE","BM3_PsMs","BM3_CSV","Q78.1"]]
df4[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q43_4_3","BM4_PLO","BM4_SE","BM4_PsMs","BM4_CSV","Q78.1"]]
df5[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q43_5_3","BM5_PLO","BM5_SE","BM5_PsMs","BM5_CSV","Q78.1"]]
df6[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q43_6_3","BM6_PLO","BM6_SE","BM6_PsMs","BM6_CSV","Q78.1"]]
df7[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q43_7_3","BM7_PLO","BM7_SE","BM7_PsMs","BM7_CSV","Q78.1"]]
df8[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q43_8_3","BM8_PLO","BM8_SE","BM8_PsMs","BM8_CSV","Q78.1"]]
df9[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q43_9_3","BM9_PLO","BM9_SE","BM9_PsMs","BM9_CSV","Q78.1"]]
df10[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q43_10_3","BM10_PLO","BM10_SE","BM10_PsMs","BM10_CSV","Q78.1"]]
pdList = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]
BM = pd.concat(pdList)
BM["Exp"] = "BM"
BM = BM[BM["Q"].notnull()]

df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()
df10 = pd.DataFrame()
df1[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q62_1_3","SS1_PLO","SS1_SE","SS1_PsMs","SS1_CSV","Q78.1"]]
df2[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q62_2_3","SS2_PLO","SS2_SE","SS2_PsMs","SS2_CSV","Q78.1"]]
df3[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q62_3_3","SS3_PLO","SS3_SE","SS3_PsMs","SS3_CSV","Q78.1"]]
df4[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q62_4_3","SS4_PLO","SS4_SE","SS4_PsMs","SS4_CSV","Q78.1"]]
df5[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q62_5_3","SS5_PLO","SS5_SE","SS5_PsMs","SS5_CSV","Q78.1"]]
df6[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q62_6_3","SS6_PLO","SS6_SE","SS6_PsMs","SS6_CSV","Q78.1"]]
df7[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q62_7_3","SS7_PLO","SS7_SE","SS7_PsMs","SS7_CSV","Q78.1"]]
df8[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q62_8_3","SS8_PLO","SS8_SE","SS8_PsMs","SS8_CSV","Q78.1"]]
df9[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q62_9_3","SS9_PLO","SS9_SE","SS9_PsMs","SS9_CSV","Q78.1"]]
df10[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q62_10_3","SS10_PLO","SS10_SE","SS10_PsMs","SS10_CSV","Q78.1"]]
pdList = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]
SS = pd.concat(pdList)
SS["Exp"] = "SS"
SS = SS[SS["Q"].notnull()]

df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()
df10 = pd.DataFrame()
df1[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q80_1_3","SG1_PLO","SG1_SE","SG1_PsMs","SG1_CSV","Q78.1"]]
df2[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q80_2_3","SG2_PLO","SG2_SE","SG2_PsMs","SG2_CSV","Q78.1"]]
df3[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q80_3_3","SG3_PLO","SG3_SE","SG3_PsMs","SG3_CSV","Q78.1"]]
df4[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q80_4_3","SG4_PLO","SG4_SE","SG4_PsMs","SG4_CSV","Q78.1"]]
df5[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q80_5_3","SG5_PLO","SG5_SE","SG5_PsMs","SG5_CSV","Q78.1"]]
df6[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q80_6_3","SG6_PLO","SG6_SE","SG6_PsMs","SG6_CSV","Q78.1"]]
df7[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q80_7_3","SG7_PLO","SG7_SE","SG7_PsMs","SG7_CSV","Q78.1"]]
df8[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q80_8_3","SG8_PLO","SG8_SE","SG8_PsMs","SG8_CSV","Q78.1"]]
df9[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q80_9_3","SG9_PLO","SG9_SE","SG9_PsMs","SG9_CSV","Q78.1"]]
df10[["ResponseId","intro/upper","Q","PLO","SE","PsMs","CSV","Gender"]] = df[["ResponseId","intro/upper","Q80_10_3","SG10_PLO","SG10_SE","SG10_PsMs","SG10_CSV","Q78.1"]]
pdList = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]
SG = pd.concat(pdList)
SG["Exp"] = "SG"
SG = SG[SG["Q"].notnull()]

# %%
dat = pd.concat([PM,BM,SS,SG])
SE_dat = dat[dat["SE"].notnull()]
PLO_dat = dat[dat["PLO"].notnull()]
PsMs_dat = dat[dat["PsMs"].notnull()]

# %%
PLO_dat
# Out:
#             ResponseId intro/upper  \
# 2    R_3hs7PgSMOaeYVMc       upper
# 3    R_1eJXpYTLRoImkQg       upper
# 4    R_3OlEEAsgu8E3JzJ       upper
# 5    R_2fJa5RK3RYGqz82       upper
# 6    R_30pjFhwE8ocKnia       upper
# ..                 ...         ...
# 56   R_A1mswrGvxdDJBnP       upper
# 73   R_12yEAWZEumKKU5T       upper
# 101  R_2aeFZcgIM7ferNw       upper
# 132  R_1jiCMKrRntpUu01       upper
# 10   R_XRh74hBRlTUpVkt       upper
#
#                                                      Q PLO SE PsMs  CSV  \
# 2                        Giving ball initial momentum,   L  S   Ps  NaN
# 3    Students are starting the ball rolling with so...   L  S   Ps  NaN
# 4    students are measuring the distance differentl...   L  S   Ms  NaN
# 5    Operator errors, not being consistent when rel...   L  S   Ps  NaN
# 6              Measurement error using the Meter stick   L  S   Ms  NaN
# ..                                                 ...  .. ..  ...  ...
# ...

# %%
SE_dat
# Out:
#             ResponseId intro/upper  \
# 2    R_3hs7PgSMOaeYVMc       upper
# 3    R_1eJXpYTLRoImkQg       upper
# 4    R_3OlEEAsgu8E3JzJ       upper
# 5    R_2fJa5RK3RYGqz82       upper
# 6    R_30pjFhwE8ocKnia       upper
# ..                 ...         ...
# 56   R_A1mswrGvxdDJBnP       upper
# 73   R_12yEAWZEumKKU5T       upper
# 101  R_2aeFZcgIM7ferNw       upper
# 132  R_1jiCMKrRntpUu01       upper
# 10   R_XRh74hBRlTUpVkt       upper
#
#                                                      Q PLO SE PsMs  CSV  \
# 2                        Giving ball initial momentum,   L  S   Ps  NaN
# 3    Students are starting the ball rolling with so...   L  S   Ps  NaN
# 4    students are measuring the distance differentl...   L  S   Ms  NaN
# 5    Operator errors, not being consistent when rel...   L  S   Ps  NaN
# 6              Measurement error using the Meter stick   L  S   Ms  NaN
# ..                                                 ...  .. ..  ...  ...
# ...

# %%
PLO_dat.to_csv("PLO_dat_full.csv")

# %%
PsMs_dat

# %%
def set_random_seed(seed=0):
  np.random.seed(seed)
  random.seed(seed)
  #tf.random.set_seed(seed)

# %%
from sklearn import model_selection, naive_bayes, svm, linear_model, ensemble, neighbors
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from keras.preprocessing.text import Tokenizer

# %%
def cohens_kappa(tp,fp,fn,tn):
    num = 2* (tp*tn - fn*fp)
    denom = (tp+fp)*(fp+tn) + (tp+fn)*(fn+tn)
    return num/denom

# %%
#word pre-processing here
def preprocess_text(para):
    # Remove punctuations and numbers
    para = re.sub('[^a-zA-Z]', ' ', para)
    # Single character removal
    para = re.sub(r"\s+[a-zA-Z]\s+", ' ', para)
    # Removing multiple spaces
    para = re.sub(r'\s+', ' ', para)
    
    tokens = para.split()
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    
    return tokens

Xt = []
for response in SE_dat["Q"].tolist():
    Xt.append(preprocess_text(response))
    
y = np.array(SE_dat["SE"].tolist())
y

# %%
def make_split(s):
    set_random_seed(seed=s)
    Train_X, Test_X, Train_y, Test_y = model_selection.train_test_split(Xt,y,test_size=0.1)
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(Train_X)
    # encode training data set
    Xtrain = tokenizer.texts_to_matrix(Train_X, mode="binary")
    # encode training data set
    Xtest = tokenizer.texts_to_matrix(Test_X, mode="binary")
    return tokenizer, Xtrain, Xtest, Train_y, Test_y

# %%
def naivebayes1(s,tokenizer, Xtrain, Xtest, Train_y, Test_y):
    set_random_seed(seed = s)
    # fit the training dataset on the NB classifier
    Naive = naive_bayes.MultinomialNB()
    Naive.fit(Xtrain,Train_y)
    # predict the labels on validation dataset
    predictions_NB = Naive.predict(Xtest)
    # Use accuracy_score function to get the accuracy
    #print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_NB, Test_y)*100)
    #print("Naive Bayes Precision Score -> ",precision_score(predictions_NB, Test_y)*100)
    #print("Naive Bayes Recall Score -> ",recall_score(predictions_NB, Test_y)*100)
    # Confusion Matrix
    #print("Naive Bayes Confusion Matrix -> ",confusion_matrix(predictions_NB, Test_y))
    #tn, fp, fn, tp = confusion_matrix(predictions_NB, Test_y).ravel()
    #k = cohens_kappa(tp,fp,fn,tn)
    k = 0
    return accuracy_score(predictions_NB, Test_y),precision_score(predictions_NB, Test_y,average = "weighted"),recall_score(predictions_NB, Test_y,average = "weighted"),k

# %%
def svm1(s,tokenizer, Xtrain, Xtest, Train_y, Test_y):
    set_random_seed(seed = s)
    # Classifier - Algorithm - SVM
    # fit the training dataset on the classifier
    SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
    SVM.fit(Xtrain,Train_y)
    # predict the labels on validation dataset
    predictions_SVM = SVM.predict(Xtest)
    #tn, fp, fn, tp = confusion_matrix(predictions_SVM, Test_y).ravel()
    print(confusion_matrix(predictions_SVM, Test_y).ravel())
    #k = cohens_kappa(tp,fp,fn,tn)
    k=0
    return accuracy_score(predictions_SVM, Test_y),precision_score(predictions_SVM, Test_y,average = "weighted"),recall_score(predictions_SVM, Test_y,average = "weighted"),k

# %%
def logreg1(s,tokenizer, Xtrain, Xtest, Train_y, Test_y):
    set_random_seed(seed = s)
    Log = linear_model.LogisticRegression(random_state = s, max_iter = 10000)
    Log.fit(Xtrain,Train_y)
    # predict the labels on validation dataset
    predictions_Log = Log.predict(Xtest)
    # Use accuracy_score function to get the accuracy
    #print("Logistic Regression Accuracy Score -> ",accuracy_score(predictions_Log, Test_y)*100)
    # Confusion Matrix
    print("Logistic Regression Confusion Matrix -> ",confusion_matrix(predictions_Log, Test_y))
    #tn, fp, fn, tp = confusion_matrix(predictions_Log, Test_y).ravel()
    #k = cohens_kappa(tp,fp,fn,tn)
    k =0
    return accuracy_score(predictions_Log, Test_y),precision_score(predictions_Log, Test_y,average = "weighted"),recall_score(predictions_Log, Test_y,average = "weighted"),k

# %%
def randFor1(s,tokenizer, Xtrain, Xtest, Train_y, Test_y):
    set_random_seed(seed = s)
    RF = ensemble.RandomForestClassifier(n_estimators =400,criterion="entropy",random_state =s)
    RF.fit(Xtrain,Train_y)
    # predict the labels on validation dataset
    predictions_RF = RF.predict(Xtest)
    #tn, fp, fn, tp = confusion_matrix(predictions_RF, Test_y).ravel()
    #k = cohens_kappa(tp,fp,fn,tn)
    k=0
    return accuracy_score(predictions_RF, Test_y),precision_score(predictions_RF, Test_y,average = "weighted"),recall_score(predictions_RF, Test_y,average = "weighted"),k

# %%
def KNN1(s,tokenizer, Xtrain, Xtest, Train_y, Test_y):
    set_random_seed(seed = s)
    kNN = neighbors.KNeighborsClassifier(n_neighbors = 3, p = 1)
    kNN.fit(Xtrain,Train_y)
    # predict the labels on validation dataset
    predictions_kNN = kNN.predict(Xtest)
    #tn, fp, fn, tp = confusion_matrix(predictions_kNN, Test_y).ravel()
    #k = cohens_kappa(tp,fp,fn,tn)
    k = 0
    return accuracy_score(predictions_kNN, Test_y),precision_score(predictions_kNN, Test_y),recall_score(predictions_kNN, Test_y),k

# %%
acc = []
prec = []
rec = []
kap = []
for seed in range(40):
    tokenizer, Xtrain, Xtest, Train_y, Test_y = make_split(seed)
    a,p,r,k = svm1(seed,tokenizer, Xtrain, Xtest, Train_y, Test_y)
    acc.append(a)
    prec.append(p)
    rec.append(r)
    kap.append(k)
print("SVM")
print("Accuracy:")
print(np.mean(acc))
print(np.std(acc))
print("Precision:")
print(np.mean(prec))
print(np.std(prec))
print("Recall:")
print(np.mean(rec))
print(np.std(rec))
print("Kappa:")
print(np.mean(kap))
print(np.std(kap))

# %%
acc = []
prec = []
rec = []
kap = []
for seed in range(20):
    tokenizer, Xtrain, Xtest, Train_y, Test_y = make_split(seed)
    a,p,r,k = logreg1(seed,tokenizer, Xtrain, Xtest, Train_y, Test_y)
    acc.append(a)
    prec.append(p)
    rec.append(r)
    kap.append(k)
print("Logistic Regression")
print("Accuracy:")
print(np.mean(acc))
print(np.std(acc))
print("Precision:")
print(np.mean(prec))
print(np.std(prec))
print("Recall:")
print(np.mean(rec))
print(np.std(rec))
print("Kappa:")
print(np.mean(kap))
print(np.std(kap))

# %%
acc = []
prec = []
rec = []
kap = []
for seed in range(20):
    tokenizer, Xtrain, Xtest, Train_y, Test_y = make_split(seed)
    a,p,r,k = randFor1(seed,tokenizer, Xtrain, Xtest, Train_y, Test_y)
    acc.append(a)
    prec.append(p)
    rec.append(r)
    kap.append(k)
print("Random Forest")
print("Accuracy:")
print(np.mean(acc))
print(np.std(acc))
print("Precision:")
print(np.mean(prec))
print(np.std(prec))
print("Recall:")
print(np.mean(rec))
print(np.std(rec))
print("Kappa:")
print(np.mean(kap))
print(np.std(kap))

# %%
acc = []
prec = []
rec = []
kap = []
for seed in range(20):
    tokenizer, Xtrain, Xtest, Train_y, Test_y = make_split(seed)
    a,p,r,k = naivebayes1(seed,tokenizer, Xtrain, Xtest, Train_y, Test_y)
    acc.append(a)
    prec.append(p)
    rec.append(r)
    kap.append(k)
print("Naive Bayes")
print(np.mean(acc))
print(np.std(acc))
print(np.mean(prec))
print(np.std(prec))
print(np.mean(rec))
print(np.std(rec))
print(np.mean(kap))
print(np.std(kap))
#svm1, logreg1, randFor1, KNN1, neural_net

# %%
acc = []
prec = []
rec = []
kap = []
for seed in range(20):
    tokenizer, Xtrain, Xtest, Train_y, Test_y = make_split(seed)
    a,p,r,k = KNN1(seed,tokenizer, Xtrain, Xtest, Train_y, Test_y)
    acc.append(a)
    prec.append(p)
    rec.append(r)
    kap.append(k)
print("k Nearest Neighbors")
print(np.mean(acc))
print(np.std(acc))
print(np.mean(prec))
print(np.std(prec))
print(np.mean(rec))
print(np.std(rec))
print(np.mean(kap))
print(np.std(kap))
#svm1, logreg1, randFor1, KNN1, neural_net
